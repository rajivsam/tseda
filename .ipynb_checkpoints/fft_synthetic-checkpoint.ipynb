# %%
from dataloader.synthetic_series_data_loader import SyntheticSeriesDataLoader
import numpy as np

# %%
sd = SyntheticSeriesDataLoader()

# %%
s = sd.get_series()

# %%
from periodicity.fft_analyzer import FFT_Analyzer

# %%
ffta = FFT_Analyzer(s, fmin=1/48, fmax=1/2)

# %%
ffta.plot()

# %%
1/24
# Out:
# 0.041666666666666664

# %%
from visualization.autocorrelation_vis import ACFPlotter

# %%
ap = ACFPlotter(s, lags = 48)

# %%
ap.calc_ACF().show()
